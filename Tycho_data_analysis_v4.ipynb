# %% [markdown]
# # *** Run in Snowflakes Environment ***

# %% [markdown]
# # Working with datasets
#
# Some ideas for using ML nd Scikit-Learn/Tensorflow:
#
# Gaia Data
#     looking for eclipse data (Fourier Transform??)
# Market Data
# Economic Data
# Analysing Astrophotos
# Company Data (structured/unstructured) as a predictor for performance
# Event Predictors (e.g. Fires, Shopping trends, Disease or Illness outbreaks)
# Credit (ACM??)
# Probability of Default predictor?

# %%
from os import path
#fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/light_curves_v1.csv')
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.02.gz')

# %%
path.getsize(fname)
# Out:
# 8351549

# %%
path.getsize(fname) / (1<<20)
# Out:
# 7.964657783508301

# %% [markdown]
# 1-  4  I4      ---     TYC1     [1,9537]+= TYC1 from TYC or GSC (1)
#    6- 10  I5      ---     TYC2     [1,12121]  TYC2 from TYC or GSC (1)
#       12  I1      ---     TYC3     [1,3]      TYC3 from TYC (1)
#       14  A1      ---     pflag    [ PX] mean position flag (2)
#   16- 27  F12.8   deg     RAmdeg   []? Mean Right Asc, ICRS, epoch=J2000 (3)
#   29- 40  F12.8   deg     DEmdeg   []? Mean Decl, ICRS, at epoch=J2000 (3)
#   42- 48  F7.1    mas/yr  pmRA     ? Proper motion in RA*cos(dec) (12)
#   50- 56  F7.1    mas/yr  pmDE     ? Proper motion in Dec (12)
#   58- 60  I3      mas    e_RAmdeg  [3,183]? s.e. RA*cos(dec),at mean epoch (5)
#   62- 64  I3      mas    e_DEmdeg  [1,184]? s.e. of Dec at mean epoch (5)
#   66- 69  F4.1    mas/yr  e_pmRA   [0.2,11.5]? s.e. prop mot in RA*cos(dec)(5)
#   71- 74  F4.1    mas/yr  e_pmDE   [0.2,10.3]? s.e. of proper motion in Dec(5)
#   76- 82  F7.2    yr      EpRAm    [1915.95,1992.53]? mean epoch of RA (4)
#   84- 90  F7.2    yr      EpDEm    [1911.94,1992.01]? mean epoch of Dec (4)
#   92- 93  I2      ---     Num      [2,36]? Number of positions used
#   95- 97  F3.1    ---    q_RAmdeg  [0.0,9.9]? Goodness of fit for mean RA (6)
#   99-101  F3.1    ---    q_DEmdeg  [0.0,9.9]? Goodness of fit for mean Dec (6)
#  103-105  F3.1    ---     q_pmRA   [0.0,9.9]? Goodness of fit for pmRA (6)
#  107-109  F3.1    ---     q_pmDE   [0.0,9.9]? Goodness of fit for pmDE (6)
#  111-116  F6.3    mag     BTmag    [2.183,16.581]? Tycho-2 BT magnitude (7)
#  118-122  F5.3    mag     e_BTmag  [0.014,1.977]? s.e. of BT (7)
#  124-129  F6.3    mag     VTmag    [1.905,15.193]? Tycho-2 VT magnitude (7)
#  131-135  F5.3    mag     e_VTmag  [0.009,1.468]? s.e. of VT (7)
#  137-139  I3    0.1arcsec prox     [3,999] proximity indicator (8)
#      141  A1      ---     TYC      [T] Tycho-1 star (9)
#  143-148  I6      ---     HIP      [1,120404]? Hipparcos number
#  149-151  A3      ---     CCDM     CCDM component identifier for HIP stars(10)
#  153-164  F12.8   deg     RAdeg    Observed Tycho-2 Right Ascension, ICRS
#  166-177  F12.8   deg     DEdeg    Observed Tycho-2 Declination, ICRS
#  179-182  F4.2    yr    EpRA-1990  [0.81,2.13]  epoch-1990 of RAdeg
#  184-187  F4.2    yr    EpDE-1990  [0.72,2.36]  epoch-1990 of DEdeg
#  189-193  F5.1    mas     e_RAdeg  s.e.RA*cos(dec), of observed Tycho-2 RA (5)
#  195-199  F5.1    mas     e_DEdeg  s.e. of observed Tycho-2 Dec (5)
#      201  A1      ---     posflg   [ DP] type of Tycho-2 solution (11)
#  203-206  F4.1    ---     corr     [-1,1] correlation (RAdeg,DEdeg)

# %% [markdown]
# # This shows how to read data where the is no header and how to define the column names using "names=[...]" as a parameter

# %%
import pandas as pd
#df = pd.read_fwf(fname,  compression='gzip', colspecs=[(1,4),(6,10),(12,12),(14,14),(16,27),(29,40),(42,48),(50,56),(58,60),(62,64),(66,69),(71,74)])
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.00.gz')
df = pd.read_fwf(fname,  compression='gzip', header=None, names=['RA','DEC', 'B','V'],colspecs=[(15,26),(28,39),(110,115),(123,128)])
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.01.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.02.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.03.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.04.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.05.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.06.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.07.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.08.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.09.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.10.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.11.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.12.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.13.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.14.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.15.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.16.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.17.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.18.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
fname = path.expanduser('~/Desktop/Ex_Files_Data_Science_Python/Exercise Files/tyc2.dat.19.gz')
df = df.append(pd.read_fwf(fname,  compression='gzip',names=['RA','DEC', 'B','V'], header=None,colspecs=[(15,26),(28,39),(110,115),(123,128)]),ignore_index=True)
df.head()
#df = pd.read_csv(fname, header=0, compression='gzip', sep='|',usecols=[2,3,17,19])
#df = pd.read_csv(fname, sep='|') #,usecols=[2,3])
#df = pd.read_csv(fname)
#df
# Out:
#          RA       DEC      B      V
# 0  2.317505  2.231843  12.14  12.14
# 1  1.125582  2.267394  10.48   8.67
# 2  1.056865  1.897829  12.92  12.10
# 3  0.050598  1.771443  11.31  10.52
# 4  0.050598  1.771443  10.77  10.09

# %%
df['B-V']=df['B']-df['V']
df
# Out:
#                  RA        DEC      B      V   B-V
# 0          2.317505   2.231843  12.14  12.14  0.00
# 1          1.125582   2.267394  10.48   8.67  1.81
# 2          1.056865   1.897829  12.92  12.10  0.82
# 3          0.050598   1.771443  11.31  10.52  0.79
# 4          0.050598   1.771443  10.77  10.09  0.68
# 5          0.372201   2.480188  12.19  11.39  0.80
# 6          1.027665   1.458492  12.68  12.28  0.40
# 7          0.774317   1.710595  12.53  11.69  0.84
# 8          0.298386   1.923618  11.67  11.64  0.03
# 9          2.371418   2.304003   9.51   9.38  0.13
# 10              NaN        NaN  13.03  12.23  0.80
# 11         1.082340   2.122620  12.67  12.20  0.47
# 12         0.878068   2.315968  12.19  11.44  0.75
# 13         2.465935   2.048472  12.40  11.63  0.77
# 14         1.264666   1.037707   9.71   8.90  0.81
# 15         1.955853   2.060288  12.71  12.52  0.19
# 16         1.864208   2.084216  12.91  12.49  0.42
# ...

# %%
len(df['RA'])
# Out:
# 2539913

# %%
#df.columns
df.columns
# Out:
# Index(['RA', 'DEC', 'B', 'V', 'B-V'], dtype='object')

# %%
df.loc[0:12]
# Out:
#           RA       DEC      B      V   B-V
# 0   2.317505  2.231843  12.14  12.14  0.00
# 1   1.125582  2.267394  10.48   8.67  1.81
# 2   1.056865  1.897829  12.92  12.10  0.82
# 3   0.050598  1.771443  11.31  10.52  0.79
# 4   0.050598  1.771443  10.77  10.09  0.68
# 5   0.372201  2.480188  12.19  11.39  0.80
# 6   1.027665  1.458492  12.68  12.28  0.40
# 7   0.774317  1.710595  12.53  11.69  0.84
# 8   0.298386  1.923618  11.67  11.64  0.03
# 9   2.371418  2.304003   9.51   9.38  0.13
# 10       NaN       NaN  13.03  12.23  0.80
# 11  1.082340  2.122620  12.67  12.20  0.47
# 12  0.878068  2.315968  12.19  11.44  0.75

# %%
import folium

# %% [markdown]
# ecliptic to equatorial (in degrees):
# α=tan−1((sin(λ)∗cos(ϵ)−tan(β)∗sin(ϵ)/cos(λ))
# numpy.arctan2(x1, x2, /, out=None, *, where=True, casting='same_kind', order='K', dtype=None, subok=True[, signature, extobj]) = <ufunc 'arctan2'>
#
# δ=sin−1(sin(β)∗cos(ϵ)+cos(β)∗sin(ϵ)∗sin(λ))
#
# Where
# ϵ
# is the obliquity of the ecliptic based on your reference epoch.
# Then equatorial to galactic:
# b=sin−1(cos(δ)∗cos(27.4)∗cos(α−192.25)+sin(δ)∗sin(27.4))
# l=tan−1(sin(δ)−sin(b)∗sin(27.4)cos(δ)∗cos(27.4)∗sin(α−192.25))+33
# The numbers for the formula come from how the galactic is setup where
# α=192.25
# for the north pole and
# δ=27.4
# for the ascending node of the galactic plane where the equator
# l=33
# NOTE: Whenever you compute the inverse tangent you have to remove the ambiguity based on the quadrant. For example
# tan−1=yx
# The angle is between 0-90 if both x & y are positive. The angle is between 90-180 if y is positive and x is negative. The angle is 180-270 if both x and y are negative. The angle is between 270 and 360 if y is negative and x is positive. Just add or subtract 180 or 360 to put the result in the correct quadrant.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import mpl_toolkits

# plt.style.use('seaborn-whitegrid')

#m = Basemap(projection='hammer',lon_0=180)

plt.rcParams['figure.figsize'] = (24, 16)
# unit area ellipse
#rx, ry = 1., 1.
#area = rx * ry * np.pi
#theta = np.arange(0, 2 * np.pi + 0.01, 0.1)

ex,ey,Vmag = df['RA'].dropna(),df['DEC'].dropna(), df['V'].dropna()

# coordinate transformation
#delta_ra=1.3*2*np.pi
delta_ra=80
seconddelta_ra=210
#epsilon = .17*2*np.pi
epsilon = .165*2*np.pi
ex = (ex+delta_ra) % 360
ex = (ex-180)*np.pi/180

ey = ey*np.pi/180

x = np.arctan2(np.sin(ex)*np.cos(epsilon)-np.tan(ey)*np.sin(epsilon),np.cos(ex))
y = np.arcsin(np.sin(ey)*np.cos(epsilon)+np.cos(ey)*np.sin(epsilon)*np.sin(ex))
x = 180 * x / np.pi + 180
x = 180 - (x+seconddelta_ra) % 360
x = x*np.pi/180

#x = (ex-180)*np.pi/180
#y = ey*np.pi/180

#s *= 10**2.

fig, ax = plt.subplots()
#ax.scatter(df['RA'],df['DEC'], 0.05, c=df['B-V']*10-12, cmap='hsv')
#ax.scatter(df['RA'],df['DEC'], 0.05, c=df['B-V']+0.6, cmap='Spectral')
#ax.scatter(df['RA'],df['DEC'], 0.05, c=df['B-V']*0.0000000002, cmap='Spectral')

#theta = 2 * np.pi * np.random.rand(N)
#area = 200 * r**2
#colors = theta
#fig = plt.figure()

ax = fig.add_subplot(111, projection='hammer')
#c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)
#plt.subplot(projection="hammer")
ax.set_facecolor((0, 0, 0.1))
plt.scatter(x,y,50/Vmag**5,marker='o',color='white',cmap='Spectral')
#plt.scatter(x,y,0.00001,marker='o',color='white',cmap='Spectral')
plt.show()
x.head(20)
# Out:
# 0    -1.850853
# 1    -1.814662
# 2    -1.809786
# 3    -1.778149
# 4    -1.778149
# 5    -1.793604
# 6    -1.805494
# 7    -1.799685
# 8    -1.786911
# 9    -1.852982
# 11   -1.812266
# 12   -1.807534
# 13   -1.854243
# 14   -1.809580
# 15   -1.838563
# 16   -1.835907
# 17   -1.830023
# 18   -1.842055
# 19   -1.803067
# 20   -1.839484
# dtype: float64

# %%
10**2
# Out:
# 100

# %%
df.dtypes
# Out:
# RA     float64
# DEC    float64
# B      float64
# V      float64
# B-V    float64
# dtype: object

# %% [markdown]
# # Remember that Source_ID is an integer, not a string
#
# So you need to do the slice using an integer with no apostrophes

# %%
df.index = df['source_id']

df1 = df[1042504286338226688:1042504286338226688]

df[1042504286338226688:1042504286338226688]
#df1
#df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-11f577d11e60> in <module>()
# ----> 1 df.index = df['source_id']
#       2
# ...

# %%
df.iloc[2:7]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

#fig.savefig("test.png")
plt.show()

# %%
import folium

# %%
HOME_COORDINATES = (51.24806, -0.539167)
m = folium.Map(location = HOME_COORDINATES, tiles = 'Stamen Terrain', zoom_start = 15)
home_marker = folium.CircleMarker(HOME_COORDINATES,radius=5, color = 'red')
home_marker.add_to(m)
m

# %%
HOME_COORDINATES = (51.24806, -0.539167)
m_space = folium.Map(location = HOME_COORDINATES, tiles = '', zoom_start = 15)
home_marker = folium.CircleMarker(HOME_COORDINATES,radius=5, color = 'red')
home_marker.add_to(m_space)
m_space
